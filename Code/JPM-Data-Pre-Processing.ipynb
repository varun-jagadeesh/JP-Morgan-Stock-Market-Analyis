# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as ss
from scipy.optimize import minimize
from sklearn.metrics import mean_squared_error

# %%
df_fama_5  = pd.read_csv('FF5factors.CSV')

# %%
df_fama_5.head()
# Out:
#        Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0  19630701   -0.67  0.00 -0.32 -0.01  0.15  0.012
# 1  19630702    0.79 -0.27  0.27 -0.07 -0.19  0.012
# 2  19630703    0.63 -0.17 -0.09  0.17 -0.33  0.012
# 3  19630705    0.40  0.08 -0.28  0.08 -0.33  0.012
# 4  19630708   -0.63  0.04 -0.18 -0.29  0.13  0.012

# %%
df_fama_5 = df_fama_5[df_fama_5.Date > 20160515]

# %%
df_fama_5.shape
# Out:
# (997, 7)

# %%
df_fama_5.head()
# Out:
#            Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 13309  20160516    0.99  0.20 -0.24 -0.05 -0.31  0.001
# 13310  20160517   -0.95 -0.68  0.61 -0.12 -0.10  0.001
# 13311  20160518    0.10  0.14  0.83 -1.34 -0.65  0.001
# 13312  20160519   -0.33 -0.31 -0.30  0.39 -0.01  0.001
# 13313  20160520    0.75  0.84 -0.30 -0.39 -0.38  0.001

# %%
df_fama_5.reset_index(drop = True, inplace= True)

# %%
df_fama_5.head()
# Out:
#        Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0  20160516    0.99  0.20 -0.24 -0.05 -0.31  0.001
# 1  20160517   -0.95 -0.68  0.61 -0.12 -0.10  0.001
# 2  20160518    0.10  0.14  0.83 -1.34 -0.65  0.001
# 3  20160519   -0.33 -0.31 -0.30  0.39 -0.01  0.001
# 4  20160520    0.75  0.84 -0.30 -0.39 -0.38  0.001

# %%
df_fama = pd.read_csv ('FF3factors.csv')

# %%
df_fama.head()
# Out:
#        Date  Mkt-RF   SMB   HML     RF
# 0  19260701    0.10 -0.24 -0.28  0.009
# 1  19260702    0.45 -0.32 -0.08  0.009
# 2  19260706    0.17  0.27 -0.35  0.009
# 3  19260707    0.09 -0.59  0.03  0.009
# 4  19260708    0.21 -0.36  0.15  0.009

# %%
df_fama = df_fama[df_fama.Date > 20160515]

# %%
df_fama.shape
# Out:
# (997, 5)

# %%
df_fama.head()
# Out:
#            Date  Mkt-RF   SMB   HML     RF
# 23729  20160516    0.99  0.28 -0.24  0.001
# 23730  20160517   -0.95 -0.78  0.61  0.001
# 23731  20160518    0.10  0.10  0.83  0.001
# 23732  20160519   -0.33 -0.32 -0.30  0.001
# 23733  20160520    0.75  0.90 -0.30  0.001

# %%
df_fama.tail()
# Out:
#            Date  Mkt-RF   SMB   HML   RF
# 24721  20200424    1.44  0.32 -0.09  0.0
# 24722  20200427    1.73  1.65  2.74  0.0
# 24723  20200428   -0.44  0.87  2.89  0.0
# 24724  20200429    2.92  1.87  2.04  0.0
# 24725  20200430   -1.18 -1.42 -1.63  0.0

# %%
df_fama.index = range(0, 997, 1)

# %%
df_fama.head()
# Out:
#        Date  Mkt-RF   SMB   HML     RF
# 0  20160516    0.99  0.28 -0.24  0.001
# 1  20160517   -0.95 -0.78  0.61  0.001
# 2  20160518    0.10  0.10  0.83  0.001
# 3  20160519   -0.33 -0.32 -0.30  0.001
# 4  20160520    0.75  0.90 -0.30  0.001

# %%
df_fama_5.head()
# Out:
#        Date  Mkt-RF   SMB   HML   RMW   CMA     RF
# 0  20160516    0.99  0.20 -0.24 -0.05 -0.31  0.001
# 1  20160517   -0.95 -0.68  0.61 -0.12 -0.10  0.001
# 2  20160518    0.10  0.14  0.83 -1.34 -0.65  0.001
# 3  20160519   -0.33 -0.31 -0.30  0.39 -0.01  0.001
# 4  20160520    0.75  0.84 -0.30 -0.39 -0.38  0.001

# %%
df_fama.tail()
# Out:
#          Date  Mkt-RF   SMB   HML   RF
# 992  20200424    1.44  0.32 -0.09  0.0
# 993  20200427    1.73  1.65  2.74  0.0
# 994  20200428   -0.44  0.87  2.89  0.0
# 995  20200429    2.92  1.87  2.04  0.0
# 996  20200430   -1.18 -1.42 -1.63  0.0

# %%
df_jpm = pd.read_csv('JPM.csv')

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2016-05-16  61.209999  61.990002  61.000000  61.660000  55.047691  10951300
# 1  2016-05-17  61.430000  62.160000  61.150002  61.660000  55.047691  12180900
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466  24007100
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175  16076200
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303  11862000

# %%
df_jpm = df_jpm[df_jpm.Date <= '2020-04-30']

# %%
df_jpm.shape
# Out:
# (997, 7)

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2016-05-16  61.209999  61.990002  61.000000  61.660000  55.047691  10951300
# 1  2016-05-17  61.430000  62.160000  61.150002  61.660000  55.047691  12180900
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466  24007100
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175  16076200
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303  11862000

# %%
df_jpm.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 992  2020-04-24  90.639999  91.099998  88.489998  90.709999  90.709999
# 993  2020-04-27  91.940002  95.629997  91.540001  94.620003  94.620003
# 994  2020-04-28  97.809998  98.360001  95.029999  95.290001  95.290001
# 995  2020-04-29  99.080002  99.449997  97.269997  97.860001  97.860001
# 996  2020-04-30  95.599998  96.839996  94.550003  95.760002  95.760002
#
#        Volume
# 992  15815300
# 993  22870200
# 994  20238900
# 995  20462600
# 996  19127600

# %%
df_jpm['MktRF'] = df_fama['Mkt-RF']
df_jpm['SMB'] = df_fama['SMB']
df_jpm['HML'] = df_fama['HML']
df_jpm['RF'] = df_fama['RF']
df_jpm['RMW'] = df_fama_5['RMW']
df_jpm['CMA'] = df_fama_5['CMA']
df_jpm['SMB_5'] = df_fama_5['SMB']
df_jpm['ADS'] = df_ads['ADS_Index']

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-05-16  61.209999  61.990002  61.000000  61.660000  55.047691
# 1  2016-05-17  61.430000  62.160000  61.150002  61.660000  55.047691
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303
#
#      Volume  MktRF   SMB   HML     RF   RMW   CMA  SMB_5
# 0  10951300   0.99  0.28 -0.24  0.001 -0.05 -0.31   0.20
# 1  12180900  -0.95 -0.78  0.61  0.001 -0.12 -0.10  -0.68
# 2  24007100   0.10  0.10  0.83  0.001 -1.34 -0.65   0.14
# 3  16076200  -0.33 -0.32 -0.30  0.001  0.39 -0.01  -0.31
# 4  11862000   0.75  0.90 -0.30  0.001 -0.39 -0.38   0.84

# %%
df_jpm['yest_close']  = df_jpm['Adj Close'].shift(1) # yesterday close price

# %%
df_jpm.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 992  2020-04-24  90.639999  91.099998  88.489998  90.709999  90.709999
# 993  2020-04-27  91.940002  95.629997  91.540001  94.620003  94.620003
# 994  2020-04-28  97.809998  98.360001  95.029999  95.290001  95.290001
# 995  2020-04-29  99.080002  99.449997  97.269997  97.860001  97.860001
# 996  2020-04-30  95.599998  96.839996  94.550003  95.760002  95.760002
#
#        Volume  MktRF   SMB   HML   RF   RMW   CMA  SMB_5  yest_close
# 992  15815300   1.44  0.32 -0.09  0.0 -0.14  0.16   0.29   89.389999
# 993  22870200   1.73  1.65  2.74  0.0 -0.12  0.20   2.20   90.709999
# 994  20238900  -0.44  0.87  2.89  0.0  1.39  0.74   1.65   94.620003
# 995  20462600   2.92  1.87  2.04  0.0  1.22 -0.81   2.27   95.290001
# 996  19127600  -1.18 -1.42 -1.63  0.0  0.71 -0.10  -2.06   97.860001

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-05-16  61.209999  61.990002  61.000000  61.660000  55.047691
# 1  2016-05-17  61.430000  62.160000  61.150002  61.660000  55.047691
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303
#
#      Volume  MktRF   SMB   HML     RF   RMW   CMA  SMB_5  yest_close
# 0  10951300   0.99  0.28 -0.24  0.001 -0.05 -0.31   0.20         NaN
# 1  12180900  -0.95 -0.78  0.61  0.001 -0.12 -0.10  -0.68   55.047691
# 2  24007100   0.10  0.10  0.83  0.001 -1.34 -0.65   0.14   55.047691
# 3  16076200  -0.33 -0.32 -0.30  0.001  0.39 -0.01  -0.31   57.172466
# 4  11862000   0.75  0.90 -0.30  0.001 -0.39 -0.38   0.84   56.592175

# %%
df_jpm['stock_return'] = (df_jpm['Adj Close']-df_jpm['yest_close'])/(df_jpm['yest_close'])

# %%
df_jpm['stock_return'].head()
# Out:
# 0         NaN
# 1    0.000000
# 2    0.038599
# 3   -0.010150
# 4    0.001893
# Name: stock_return, dtype: float64

# %%
#df_jpm['stock_return'].iloc[0] = 0.0

# %%
temp = df_jpm.drop(df_jpm.index[[0,1]])

# %%
temp.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303
# 5  2016-05-23  63.450001  63.869999  63.160000  63.459999  56.654667
# 6  2016-05-24  63.939999  64.769997  63.810001  64.540001  57.618855
#
#      Volume  MktRF   SMB   HML     RF   RMW   CMA  SMB_5  yest_close  \
# 2  24007100   0.10  0.10  0.83  0.001 -1.34 -0.65   0.14   55.047691
# 3  16076200  -0.33 -0.32 -0.30  0.001  0.39 -0.01  -0.31   57.172466
# 4  11862000   0.75  0.90 -0.30  0.001 -0.39 -0.38   0.84   56.592175
# 5   9347500  -0.18  0.26 -0.32  0.001 -0.21  0.08   0.24   56.699303
# 6  13839400   1.43  0.68 -0.34  0.001 -0.10 -0.39   0.61   56.654667
#
#    stock_return
# 2      0.038599
# 3     -0.010150
# 4      0.001893
# 5     -0.000787
# 6      0.017019

# %%
df_jpm.reset_index(drop = True, inplace= True)

# %% [markdown]
# #### STOCK RETURN

# %%
df_jpm['stock_return'] = (df_jpm['Adj Close']-df_jpm['yest_close'])/(df_jpm['yest_close'])

# %% [markdown]
# #### LOG RETURN

# %%
df_jpm['log_return'] = np.log(df_jpm['Close']).diff().dropna()

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 2  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466
# 3  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175
# 4  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303
# 5  2016-05-23  63.450001  63.869999  63.160000  63.459999  56.654667
# 6  2016-05-24  63.939999  64.769997  63.810001  64.540001  57.618855
#
#      Volume  MktRF   SMB   HML     RF   RMW   CMA  SMB_5  yest_close  \
# 2  24007100   0.10  0.10  0.83  0.001 -1.34 -0.65   0.14   55.047691
# 3  16076200  -0.33 -0.32 -0.30  0.001  0.39 -0.01  -0.31   57.172466
# 4  11862000   0.75  0.90 -0.30  0.001 -0.39 -0.38   0.84   56.592175
# 5   9347500  -0.18  0.26 -0.32  0.001 -0.21  0.08   0.24   56.699303
# 6  13839400   1.43  0.68 -0.34  0.001 -0.10 -0.39   0.61   56.654667
#
#    stock_return  log_return
# 2      0.038599         NaN
# 3     -0.010150   -0.010202
# 4      0.001893    0.001891
# ...

# %%
df_jpm.reset_index(drop = True, inplace= True)

# %%
df_jpm.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-05-18  61.700001  64.169998  61.689999  64.040001  57.172466
# 1  2016-05-19  63.529999  64.220001  62.900002  63.389999  56.592175
# 2  2016-05-20  63.860001  64.190002  63.369999  63.509998  56.699303
# 3  2016-05-23  63.450001  63.869999  63.160000  63.459999  56.654667
# 4  2016-05-24  63.939999  64.769997  63.810001  64.540001  57.618855
#
#      Volume  MktRF   SMB   HML     RF   RMW   CMA  SMB_5  yest_close  \
# 0  24007100   0.10  0.10  0.83  0.001 -1.34 -0.65   0.14   55.047691
# 1  16076200  -0.33 -0.32 -0.30  0.001  0.39 -0.01  -0.31   57.172466
# 2  11862000   0.75  0.90 -0.30  0.001 -0.39 -0.38   0.84   56.592175
# 3   9347500  -0.18  0.26 -0.32  0.001 -0.21  0.08   0.24   56.699303
# 4  13839400   1.43  0.68 -0.34  0.001 -0.10 -0.39   0.61   56.654667
#
#    stock_return  log_return
# 0      0.038599         NaN
# 1     -0.010150   -0.010202
# 2      0.001893    0.001891
# ...

# %%
df_jpm['log_return'].iloc[0] = 0.0
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_jpm
# Out:
#            Date        Open        High        Low       Close   Adj Close  \
# 0    2016-05-18   61.700001   64.169998  61.689999   64.040001   57.172466
# 1    2016-05-19   63.529999   64.220001  62.900002   63.389999   56.592175
# 2    2016-05-20   63.860001   64.190002  63.369999   63.509998   56.699303
# 3    2016-05-23   63.450001   63.869999  63.160000   63.459999   56.654667
# 4    2016-05-24   63.939999   64.769997  63.810001   64.540001   57.618855
# 5    2016-05-25   64.940002   66.199997  64.919998   65.519997   58.493767
# 6    2016-05-26   65.570000   65.580002  64.910004   65.029999   58.056301
# 7    2016-05-27   65.209999   65.459999  65.050003   65.430000   58.413418
# 8    2016-05-31   65.730003   65.820000  64.959999   65.269997   58.270561
# 9    2016-06-01   64.760002   65.919998  64.260002   65.690002   58.645523
# 10   2016-06-02   65.519997   65.809998  65.160004   65.809998   58.752651
# ...

# %%
df_jpm=temp.copy()

# %%
df_fama_jpm = df_jpm.to_csv('df_jpm.csv',index=False)

# %%
df_ads = pd.read_csv('ads.csv')

# %%
df_ads.head()
# Out:
#      Date  ADS_Index
# 0  3/1/60  -2.395069
# 1  3/2/60  -2.369012
# 2  3/3/60  -2.341905
# 3  3/4/60  -2.313746
# 4  3/5/60  -2.284532
